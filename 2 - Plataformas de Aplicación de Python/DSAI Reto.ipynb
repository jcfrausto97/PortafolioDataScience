# %% [markdown]
# # Sección nueva

# %% [markdown]
# Montar drive en caso de tener los datos ahí

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Importar frameworks

# %%
import pandas as pd
employees = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Módulo 2/Reto/Employee_Attrition.csv')
employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3001 entries, 0 to 3000
# Data columns (total 23 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Employee_ID                3000 non-null   object
#  1   Gender                     3000 non-null   object
#  2   Age                        2839 non-null   float64
#  3   Education_Level            3000 non-null   float64
#  4   Relationship_Status        3000 non-null   object
#  5   Hometown                   3000 non-null   object
#  6   Unit                       3000 non-null   object
#  7   Decision_skill_possess     3000 non-null   object
#  8   Time_of_service            2949 non-null   float64
#  9   Time_since_promotion       3000 non-null   float64
#  10  growth_rate                3000 non-null   float64
#  11  Travel_Rate                3000 non-null   float64
#  12  Post_Level                 3000 non-null   float64
# ...

# %% [markdown]
# **Recuperar la información del Archivo employee_attrition.csv**

# %%
employees
# Out:
#      Employee_ID Gender   Age  Education_Level Relationship_Status  \
# 0      EID_22713      F  32.0              5.0              Single
# 1       EID_9658      M  65.0              2.0              Single
# 2      EID_22203      M  52.0              3.0             Married
# 3       EID_7652      M  50.0              5.0              Single
# 4       EID_6516      F  44.0              3.0             Married
# ...          ...    ...   ...              ...                 ...
# 2996   EID_10066      F   NaN              2.0              Single
# 2997    EID_7126      F  60.0              4.0              Single
# 2998    EID_4929      F  51.0              1.0             Married
# 2999   EID_24750      F  45.0              1.0              Single
# 3000         NaN    NaN   NaN              NaN                 NaN
#
#          Hometown       Unit Decision_skill_possess  Time_of_service  \
# 0     Springfield        R&D             Conceptual         7.000000
# ...

# %% [markdown]
# **El tiempo de servicio promedio de los trabajadores**

# %%
employees["Time_of_service"].mean()
# Out:
# 13.403805433102747

# %% [markdown]
# **El porcentaje de hombres y mujeres en el archivo**

# %%
contF = employees[employees['Gender'] == 'F']
contM = employees[employees['Gender'] == 'M']

print("Total de Hombres en el archivo: ", contM['Gender'].count())
print("Total de Mujeres en el archivo: ", contF['Gender'].count())
# Out:
# Total de Hombres en el archivo:  1272
# Total de Mujeres en el archivo:  1728

# %% [markdown]
# ```
# # Esto tiene formato de código
# ```
#
# **El tiempo máximo sin promoción de las personas que llevan más de 15 años de servicio**

# %%
#x = employees[['Time_of_service','Time_since_promotion']].groupby('Time_of_service').max()
#employees[employees['Time_of_service'] > 15].groupby('Time_of_service').max()
timeprom = employees[employees["Time_of_service"]>15]

print("Tiempo máximo sin promoción de las personas que llevan más de 15 años de servicio:", timeprom["Time_since_promotion"].max(), "años")
# Out:
# Tiempo máximo sin promoción de las personas que llevan más de 15 años de servicio: 4.0 años

# %% [markdown]
# **La edad promedio en la que ingresaron las personas a la empresa, genera una nueva columna derivada mediante la formula Age - Time_of_service**

# %%
ageprom=employees['Age'].mean()
print("Edad promedio en la que ingresaron las personas a la empresa:", ageprom)
# Out:
# Edad promedio en la que ingresaron las personas a la empresa: 39.797816132441

# %% [markdown]
# ###Nueva columna

# %%
employees["edad_prom"] = employees["Age"] - employees["Time_of_service"]
employees
# Out:
#      Employee_ID Gender   Age  Education_Level Relationship_Status  \
# 0      EID_22713      F  32.0              5.0              Single
# 1       EID_9658      M  65.0              2.0              Single
# 2      EID_22203      M  52.0              3.0             Married
# 3       EID_7652      M  50.0              5.0              Single
# 4       EID_6516      F  44.0              3.0             Married
# ...          ...    ...   ...              ...                 ...
# 2996   EID_10066      F   NaN              2.0              Single
# 2997    EID_7126      F  60.0              4.0              Single
# 2998    EID_4929      F  51.0              1.0             Married
# 2999   EID_24750      F  45.0              1.0              Single
# 3000         NaN    NaN   NaN              NaN                 NaN
#
#          Hometown       Unit Decision_skill_possess  Time_of_service  \
# 0     Springfield        R&D             Conceptual         7.000000
# ...

# %% [markdown]
# **Un dataframe con las columnas Employee_ID, Relationship, Decision_skill_process que sólo contenga los registros de mujeres, solteras y con compensación tipo 2 o 3**

# %%
#resul = (employees[(employees['Compensation_and_Benefits'] == 'type2') | (employees['Compensation_and_Benefits'] =='type3') & (employees['Gender'] == 'F') & (employees['Relationship_Status'] =='Single')])
resul = (employees[(employees['Compensation_and_Benefits'] == 'type2') | (employees['Compensation_and_Benefits'] =='type3')])
resul = (resul[employees['Gender'] == 'F'])
resul = (resul[employees['Relationship_Status'] == 'Single'])
resul = resul[["Employee_ID","Relationship_Status","Decision_skill_possess"]]
resul
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
#      Employee_ID Relationship_Status Decision_skill_possess
# 0      EID_22713              Single             Conceptual
# 10     EID_13639              Single             Behavioral
# 12     EID_16537              Single              Directive
# 15      EID_1855              Single             Analytical
# 23     EID_11398              Single              Directive
# ...          ...                 ...                    ...
# 2979   EID_23052              Single             Analytical
# 2993   EID_10639              Single             Conceptual
# ...

# %% [markdown]
# **Una columna derivada con el valor "on time" si cuando tuvo su última promoción tenía menos de 30 años. En caso contrario colocar el valor de "out of time"**

# %%
employees["En_tiempo"] = employees["Age"] < (30)
employees["En_tiempo"] = employees["En_tiempo"].replace(True, 'On time')
employees["En_tiempo"] = employees["En_tiempo"].replace(False, 'Out of time')
employees
# Out:
#      Employee_ID Gender   Age  Education_Level Relationship_Status  \
# 0      EID_22713      F  32.0              5.0              Single
# 1       EID_9658      M  65.0              2.0              Single
# 2      EID_22203      M  52.0              3.0             Married
# 3       EID_7652      M  50.0              5.0              Single
# 4       EID_6516      F  44.0              3.0             Married
# ...          ...    ...   ...              ...                 ...
# 2996   EID_10066      F   NaN              2.0              Single
# 2997    EID_7126      F  60.0              4.0              Single
# 2998    EID_4929      F  51.0              1.0             Married
# 2999   EID_24750      F  45.0              1.0              Single
# 3000         NaN    NaN   NaN              NaN                 NaN
#
#          Hometown       Unit Decision_skill_possess  Time_of_service  \
# 0     Springfield        R&D             Conceptual         7.000000
# ...

# %% [markdown]
# **Guardar los dataframes resultantes**

# %%
employees.to_csv('/content/RetoFinal.csv')
