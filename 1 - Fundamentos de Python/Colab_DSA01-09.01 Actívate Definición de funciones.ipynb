# %% [markdown]
# **MÓDULO 1 - FUNDAMENTOS DE PYTHON**
#
# ---

# %% [markdown]
# ##TEMA 2. Definición de funciones

# %% [markdown]
# ***Ejemplo***

# %% [markdown]
# Calcular el área de un triángulo.
# <br>Entradas: base y altura
# <br>Salida: área del triángulo

# %%
def triangle_area(b, h):
  return b * h / 2

a = triangle_area(2.0, 5.0)
print('Area:', a)
# Out:
# Area: 5.0

# %% [markdown]
# ***Ejercicios***

# %% [markdown]
# 1. Calcular la sumatoria de un número.

# %%
def sum(a,b):
  return a + b

num1 = int(input('Ingresa el primer número: '))
num2 = int(input('Ingresa el segundo número: '))

x = sum(num1, num2)
print('La sumatoria es: ', x)
# Out:
# Ingresa el primer número: 3
# Ingresa el segundo número: 4
# La sumatoria es:  7

# %% [markdown]
# 2. Identificar si un año es bisiesto o no, considerando las siguientes dos reglas:
#
# *   Un año es bisiesto si es divisible entre 4.
# *   Un año es bisiesto si es divisible entre 100, pero también es divisible entre 400.

# %%
def bis(a):
  if (a % 4 == 0) or (a % 100 == 0) or (a % 400 == 0):
    x = 'Es bisiesto'
  else:
    x = 'No es bisiesto'
  return(x)

num = int(input('Ingresa el año a calcular: '))
var = bis(num)
print(var)
# Out:
# Ingresa el año a calcular: 2013
# ()

# %% [markdown]
# 3. Calcular la edad de un perro en años humanos, teniendo en cuenta que el primer año de un perro equivale a 15 años humanos, el segundo año de un perro equivale a 9 años humanos y de ahí en adelante cada año equivale a 4 años humanos.
#
# *   Un perro de 1 año tendría 15 años humanos
# *   Un perro de 2 años tendría 24 años humanos
# *   Un perro de 3 años tendría 28 años humanos

# %%
def edad(num) :
  if num == 1 :
    x = print("Tiene 15 años humanos")

  elif num == 2 :
    x = print("El perro tiene 24 años humanos")

  elif num == 3 :
    x = print("El perro tiene 28 años humanos")

  else :
    d= 28
    for i in range(3, num) :
        d = d + 4
    x = print("La edad del perror es: ", d)
  return (x)

num = int(input('Ingresa el año del perro: '))

print(edad(num))
# Out:
# Ingresa el año del perro: 12
# La edad del perror es:  64
# None
